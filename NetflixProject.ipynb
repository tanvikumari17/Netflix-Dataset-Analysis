# %%
# This Netflix Dataset has information about the TV Shows and Movies available on Netflix till 2021
# The Dataset is collected from Fixable which is a third-party Netflix search engine, and available on Kaggle website for free

# %%
#Import the pandas library
import pandas as pd

#Importing the dataset
data = pd.read_csv(r"C:\Users\TanviKumari\Documents\Netflix Project(csv.file).csv")
df = pd.DataFrame(data)

# %%
print(df)
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
#We will use some function to get basic information about data

df.head()                           # (head())to show top-5 records of the dataset
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
df.tail()                           #(tail()) to show bottom-5 records of the datase
# Out:
#      Show_Id Category                                    Title     Director  \
# 7784   s7783    Movie                                     Zozo  Josef Fares
# 7785   s7784    Movie                                   Zubaan  Mozez Singh
# 7786   s7785    Movie                        Zulu Man in Japan          NaN
# 7787   s7786  TV Show                    Zumbo's Just Desserts          NaN
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS     Sam Dunn
#
#                                                    Cast  \
# 7784  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7785  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7786                                            Nasty C
# 7787                         Adriano Zumbo, Rachel Khoo
# 7788                                                NaN
#
#                                                 Country        Release_Date  \
# 7784  Sweden, Czech Republic, United Kingdom, Denmar...    October 19, 2020
# ...

# %%
df.shape                            #(shape)  to show the no. of rows and no. of columns
# Out:
# (7789, 11)

# %%
df.duplicated()                  #to check row wise and detect the Duplicate rows

#This will give result in boollean form
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7784    False
# 7785    False
# 7786    False
# 7787    False
# 7788    False
# Length: 7787, dtype: bool

# %%
#to only see those records which are duplicate we will close the whole command in square bracket
df[df.duplicated()]
# this will remove all the duplicate rows but this change is not permanent
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
df.drop_duplicates(inplace = True)        # To remove the Duplicate rows permanently

# %%
df.size                           #(size)to show the total no of elements in the dataset
# Out:
# 85657

# %%
df.columns                           #(Columns) to show each column name
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
df.dtypes                           #(dtypes) to show the datatype of each column
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
df.info()                   #(info()) to show indexes, columns, data-types of each column memory at once
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7787 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7787 non-null   object
#  1   Category      7787 non-null   object
#  2   Title         7787 non-null   object
#  3   Director      5399 non-null   object
#  4   Cast          7069 non-null   object
#  5   Country       7280 non-null   object
#  6   Release_Date  7777 non-null   object
#  7   Rating        7780 non-null   object
#  8   Duration      7787 non-null   object
#  9   Type          7787 non-null   object
#  10  Description   7787 non-null   object
# dtypes: object(11)
# memory usage: 730.0+ KB

# %% [raw]
# # Task2 . Is there any Null values present in any column? Show the Heat-map.

# %%
df.isnull().sum()                           # To show where Null value is present
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
df.isnull().sum()                       #To show the count of Null values in each column
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
# !pip install seaborn
import seaborn as sns                         # To import Seaborn library
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
sns.heatmap(data.isnull())           #using heat_map to show null values count
# Out:
# <Axes: >

# %% [raw]
# Q.1. For 'House of Cards', what is the Show Id and who is the Director of this show ?

# %% [raw]
# using i.). isin()

# %%
df.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
df['Title'].isin(['House of Cards'])
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7784    False
# 7785    False
# 7786    False
# 7787    False
# 7788    False
# Name: Title, Length: 7787, dtype: bool

# %%
df[df['Title'].isin(['House of Cards'])]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %% [raw]
# ii.). using str.contains()

# %%
df[df['Title'].str.contains('House of Cards')]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %% [raw]
# Q.2. In which year highest number of the TV shows & Movies were released? Show with Bar graph.

# %% [raw]
# i.) using dtypes

# %%
df.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
#we can see Release_Date is in object format ,so we will convert it into datetime format using to_datetime function

# %% [raw]
# to_datetime

# %%
df['Release_Date'] = df['Release_Date'].str.strip()                #Remove Leading or Trailing Whitespace:

# %%
df['Date_N'] = pd.to_datetime(df['Release_Date'], format="%B %d, %Y")    #Specify the Correct Date Format:

# %%
df.dtypes
# Out:
# Show_Id                 object
# Category                object
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Release_Date            object
# Rating                  object
# Duration                object
# Type                    object
# Description             object
# Date_N          datetime64[ns]
# dtype: object

# %%
print(df)
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
df.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
##>>we will use this function to get the answer asked in our question 
dt.year.value_counts()

# %%
 df['Date_N'].dt.year.value_counts()                                # It counts the occurrence of all individual years in Date column
#Value_Counts() is used  to show the occurrence of all individual elements in any column
# Out:
# Date_N
# 2019.0    2153
# 2020.0    2009
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2008.0       2
# 2009.0       2
# 2010.0       1
# Name: count, dtype: int64

# %%
# To show the Bar graph
df['Date_N'].dt.year.value_counts().plot(kind ='bar')

# %% [raw]
# Q.3. How many Movies & TV Shows are In the dataset ? Show with Bar Graph

# %%
we will use  this function to solve the question 
i.)groupby()

# %%
df.groupby('Category').Category.count()        #to group all unique items of a column and show their count

# %%
df['Category'].str.contains('TV Show').value_counts()           #this method I tried by myself

# %%
df['Category'].str.contains('Movie').value_counts()             #this method I tried by myself

# %%
#to show the bargraph we will use 
# countplot()
df['Category'].value_counts()

# %%
category_counts = df['Category'].value_counts()

# %%
labels = category_counts.index
sizes = category_counts.values
colors = sns.color_palette('pastel', len(labels))

# %%
# # Create a pie chart
# plt.figure(figsize=(4,4))
# plt.pie(sizes, labels=labels, colors=colors, shadow=True, startangle=140)
# plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

# # Display the chart
# plt.show()

# %% [raw]
# Q.4. Show all the Movies that were released in year 2000.

# %% [raw]
# creating new column
# that will only contain year

# %%
#df['Year'] = df['Date_N'].dt.year                     #to create new Year column; it will consider only year
df['Year'] = df['Date_N'].dt.year

# %%
df.head(2)

# %%
#now we will apply filter
Filtering

# %%
# (data['category'] =='Movie') &(data['Year'] ==2020)
df[(df['Category']=='Movie') & (df['Year']==2020)]

# %% [raw]
# Q.5. Show only the Titles of all TV Shows that were released in India only.

# %%
df.head()

# %%
df[(df['Category']=='TV Show') & (df['Country']=='India')]['Title']

# %%
df[(df['Category']=='TV Show') & (df['Country']=='India')]['Show_Id']

# %% [raw]
# Q.6. Show Top 10 Directors, who gave the highest number of TV Shows & Movies to Netflix?

# %%
#we will use value_counts() function

# %%
data['Director'].value_counts().head(10)

# %%
# Q.7.Show all the Records, where "Category is Movie and type is Comedies" or " Country is United Kingdom".

# %%
Filtering (And, Or Operators)

# %%
df[(df['Category']=='Movie') & (df['Type'] == 'Comedies') | (data ['Country'] == 'United Kingdom')]

# %% [raw]
# Q.8. In how many Movies/shows, Tom Cruise was cast ?

# %%
Filtering

# %%
data.head(2)

# %%
df[df['Cast']=='Tom Cruise']

# %%
df[df['Cast'].str.contains('Tom Cruise')]

# %%
#To drop the null values we use dropna() function
data_new = df.dropna()

# %%
data_new[data_new['Cast'].str.contains('Tom Cruise')]

# %% [raw]
# Q.9. What are the different ratings defined by Netflix?

# %%
df['Rating'].nunique()           #It will give count of unique data

# %%
df['Rating'].unique()            #It will give name of Unique data

# %% [raw]
# Q.9.1. How many Movies got the 'TV-14' rating in Canada ?

# %%
df[(df['Category']=='Movie') & (df['Rating']=='TV-14') & (df['Country']== 'Canada')].shape

# %% [raw]
# Q.9.2. How many TV Show got the 'R' rating after year 2018

# %%
df.head(2)

# %%
df[(df['Category']=='Movie') & (df['Rating']=='R') & (df['Year']>2018)]

# %% [raw]
# Q.10. What is the maximum duration of a Movie/Show on Netflix ?

# %%
data.head()

# %%
df['Duration'].unique()                     #it will give the values in Duration column

# %%
df.Duration.dtypes              #To check the data types of the duration column

# %% [raw]
# #we will have to change the data type into numeric type  so for that we will split the Duration column using str.split()
#
# str.split()

# %%
df[['Minutes','Unit']] = df['Duration'].str.split(' ', expand = True)

#The Minute column wiull contain all numeric value and

# %% [raw]
# df.head(2)

# %%
#data.Minutes.max()

df['Minutes'].max()                 #It will give highest value

# %%
df['Minutes'].min()               #It will give lowest value

# %% [raw]
# Q.11. Which Individual Country has the Highest No. of TV Shows?

# %%
data_tvshow = data[data['Category']== 'TV Show']

# %%
data_tvshow.head(2)

# %%
#data_tvshow.Country.value_counts()
data_tvshow.Country.value_counts()

# %%
#data_tvshow.Country.value_counts().head(1)
data_tvshow.Country.value_counts().head(1)

# %% [raw]
# Q.12. How can we sort the dataset by year?

# %%
#data.sort_values(by = 'Year', ascending = False).head(10)

df.sort_values(by ='Year', ascending = False).head(10)
# Out:
#      Show_Id Category                                              Title  \
# 5564   s5564    Movie                                    Sherlock Holmes
# 5919   s5919    Movie                                          Surf's Up
# 980     s981  TV Show                                       Bling Empire
# 5955   s5955    Movie                                   Taare Zameen Par
# 366     s367    Movie                                          Al acecho
# 560     s561    Movie                                           Apaharan
# 1355   s1356    Movie  Chris Rock Total Blackout: The Tamborine Exten...
# 5922   s5922  TV Show                                    Surviving Death
# 4269   s4270    Movie                                                Mud
# 2799   s2800    Movie                                               Hook
#
#                      Director  \
# 5564              Guy Ritchie
# 5919  Ash Brannon, Chris Buck
# 980                       NaN
# 5955               Aamir Khan
# ...

# %% [raw]
# Q.13. Find all the Instances where Category is 'Movie' and Type is 'Dramas'
# or
# Category is 'TV Show' and Type is 'Kids'TV'

# %%
df[(df['Category']=='Movie') & (df['Type']=='Drama')]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Date_N, Year]
# Index: []

# %%
df.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %% [raw]
# ii.)Category is 'TV Show' and Type is 'Kids'TV'

# %%
df[(df['Category']=='TV Show') & (df['Type']=="Kids' TV")]
# Out:
#      Show_Id Category              Title             Director  \
# 111     s112  TV Show            44 Cats                  NaN
# 276     s277  TV Show       Abby Hatcher          Kyran Kelly
# 434     s435  TV Show        Alphablocks                  NaN
# 598     s599  TV Show  Ask the StoryBots                  NaN
# 706     s707  TV Show         Bal Ganesh  Vijay S. Bhanushali
# ...      ...      ...                ...                  ...
# 7668   s7667  TV Show      World of Winx       Iginio Straffi
# 7717   s7716  TV Show               Yoko                  NaN
# 7719   s7718  TV Show                YOM                  NaN
# 7758   s7757  TV Show                 Z4                  NaN
# 7761   s7760  TV Show          Zak Storm                  NaN
#
#                                                    Cast  \
# 111   Sarah Natochenny, Suzy Myers, Simona Berman, E...
# 276   Macy Drouin, Wyatt White, Paul Sun-Hyung Lee, ...
# ...

# %%
# Use parentheses to properly group each condition
df[(df['Category'] == 'Movie') & (df['Type'] == 'Drama') | (df['Category'] == 'TV Show') & (df['Type'] == "Kids' TV")]
# Out:
#      Show_Id Category              Title             Director  \
# 111     s112  TV Show            44 Cats                  NaN
# 276     s277  TV Show       Abby Hatcher          Kyran Kelly
# 434     s435  TV Show        Alphablocks                  NaN
# 598     s599  TV Show  Ask the StoryBots                  NaN
# 706     s707  TV Show         Bal Ganesh  Vijay S. Bhanushali
# ...      ...      ...                ...                  ...
# 7668   s7667  TV Show      World of Winx       Iginio Straffi
# 7717   s7716  TV Show               Yoko                  NaN
# 7719   s7718  TV Show                YOM                  NaN
# 7758   s7757  TV Show                 Z4                  NaN
# 7761   s7760  TV Show          Zak Storm                  NaN
#
#                                                    Cast  \
# 111   Sarah Natochenny, Suzy Myers, Simona Berman, E...
# 276   Macy Drouin, Wyatt White, Paul Sun-Hyung Lee, ...
# ...
